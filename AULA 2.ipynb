# %% [markdown]
# #### Jupyter Notebook
#
# É um ambiente que viabiliza
# - Execução de codigos
# - Criação de Documento com texto
# - Plotagem de gráficos
#
# > É frequentemente usado para notas de aulas

# %% [markdown]
# ![Wallpaper%20images_%204K,%20HD,%20Full%20HD,%20Dual%20Screen.jpg](attachment:Wallpaper%20images_%204K,%20HD,%20Full%20HD,%20Dual%20Screen.jpg)

# %%
print("Fala dev, tudo bem?")
# Out:
# Fala dev, tudo bem?

# %%
print("Bem vindo  a Aula 2!")
# Out:
# Bem vindo  a Aula 2!

# %%
import random
random.randint?

# %%
num = 3

# %%
num = num + 2

# %%
num = num * 2

# %%
print(num)
# Out:
# 9
